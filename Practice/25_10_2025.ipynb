# %% [markdown]
# **Showing type custing.**

# %%
x = str(2)

print(type(x))
# Out:
# <class 'str'>

# %%
y = int(2)

print(type(y))
# Out:
# <class 'int'>

# %%
x = str(2)

print(type(x))
# Out:
# <class 'str'>

# %%
y = int(2)

print(type(y))
# Out:
# <class 'int'>

# %%
x = str(2)

print(type(x))
# Out:
# <class 'str'>

# %%
y = int(2)

print(type(y))
# Out:
# <class 'int'>

# %%
z = float(2)
print(type(z))
# Out:
# <class 'float'>

# %%
z = float(2)
print(type(z))
# Out:
# <class 'float'>

# %%
z = float(2)
print(type(z))
# Out:
# <class 'float'>
