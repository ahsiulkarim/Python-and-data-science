# %% [markdown]
# The normal integer number printing process have been saw.

# %%
'''
This is a multi-line comment
of printing the integer number.
'''
# The integer number printing method.
print(10)

# %% [markdown]
# Floating number printing process have been seen in this part.

# %%
'''
This the multi-line comment
of the floating number.

'''
# This is the print of a floating number.
print(10.5)
